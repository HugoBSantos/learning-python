# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='https://github.com/HugoBSantos/learning-python/blob/master/Pierian_Data_Logo.png?raw=1'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Object Oriented Programming
# ## Homework Assignment
#
# #### Problem 1
# Fill in the Line class methods to accept coordinates as a pair of tuples and return the slope and distance of the line.

# %%
class Line:

    def __init__(self,coor1,coor2):
        self.coor1 = coor1
        self.coor2 = coor2

    def distance(self):
        from math import dist
        return dist(self.coor1, self.coor2)

    def slope(self):
        if self.coor2[0] - self.coor1[0] == 0:
          raise ValueError("Undefined slope: vertical line (division by zero)")
        return (self.coor2[1] - self.coor2[0]) / (self.coor1[1] - self.coor1[0])

# %%
# EXAMPLE OUTPUT

coordinate1 = (3,2)
coordinate2 = (8,10)

li = Line(coordinate1,coordinate2)
print(li.coor1)
print(li.coor2)
# Out:
# (3, 2)
# (8, 10)

# %%
li.distance()
# Out:
# 9.433981132056603

# %%
li.slope()
# Out:
# -2.0

# %% [markdown]
# ________
# #### Problem 2

# %% [markdown]
# Fill in the class

# %%
class Cylinder:

    def __init__(self,height=1,radius=1):
        self.height = height
        self.radius = radius

    def volume(self):
        from math import pi
        return pi * (self.radius ** 2) * self.height

    def surface_area(self):
        from math import pi
        return 2 * pi * self.radius * (self.height + self.radius)

# %%
# EXAMPLE OUTPUT
c = Cylinder(2,3)

# %%
c.volume()
# Out:
# 56.548667764616276

# %%
c.surface_area()
# Out:
# 94.24777960769379
